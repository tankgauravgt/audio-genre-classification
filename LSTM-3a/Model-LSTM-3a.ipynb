# %%
from scipy.io.wavfile import read as read_wav
from IPython.display import Audio
import matplotlib.pyplot as plt
import tensorflow as tf
import sklearn as skl
import librosa as lr
import numpy as np
import logging
import random
import scipy
import os

# %%
np.random.seed(5)
logging.warnings.filterwarnings('ignore')

# %%
dataset_root = '..'

# %% [markdown]
# ### Genre Dictionary:

# %%
genres = {
    'hiphop': 0,
    'metal': 1,
    'rock': 2
}

# %% [markdown]
# ### Hyper Parameters:

# %%
hparams = {
    'samplerate': 22050,
    'seq_length': 256,
    'hop_length': 512,
    'fft_window': 2048,
    'num_classes': len(genres)
}

# %% [markdown]
# ### Extract Features:

# %%
def extract_features(filepath, hparams):
    
    audio_data_array = lr.load(filepath, sr=hparams['samplerate'], mono=True)
    
    # normalized = lr.util.normalize(audio_data_array[0])
    
    features = [
        
        # MFCC Features:
        lr.feature.mfcc(
            y          = audio_data_array[0],
            sr         = hparams['samplerate'],
            hop_length = hparams['hop_length'],
            n_fft      = hparams['fft_window']
        ),

        # Chroma STFT:
        lr.feature.chroma_stft(
            y          = audio_data_array[0],
            sr         = hparams['samplerate'],
            hop_length = hparams['hop_length'],
            n_fft      = hparams['fft_window']
        ),
        
        # Spectral Centroid:
        lr.feature.spectral_centroid(
            y          = audio_data_array[0],
            sr         = hparams['samplerate'],
            hop_length = hparams['hop_length'],
            n_fft      = hparams['fft_window']
        ),
        
        # Spectral Contrast:
        lr.feature.spectral_contrast(
            y          = audio_data_array[0],
            sr         = hparams['samplerate'],
            hop_length = hparams['hop_length'],
            n_fft      = hparams['fft_window']
        )
    ]
    
    return np.vstack(features)

# %% [markdown]
# ### Hip-Hop Class:

# %%
class_1 = [
    'hiphop'
]

# %% [markdown]
# ### Metal Class:

# %%
class_2 = [
    'metal'
]

# %% [markdown]
# ### Rock Class:

# %%
class_3 = [
    'rock'
]

# %% [markdown]
# ### Allocating Arrays to Store Dataset:

# %%
train_data_x = np.zeros(shape=(5 * 210, 40, hparams['seq_length']))
val_data_x = np.zeros(shape=(5 * 60, 40, hparams['seq_length']))
test_data_x = np.zeros(shape=(5 * 30, 40, hparams['seq_length']))

train_data_y = np.zeros(shape=(5 * 210, 3))
val_data_y = np.zeros(shape=(5 * 60, 3))
test_data_y = np.zeros(shape=(5 * 30, 3))

# %% [markdown]
# ### Train Dataset:

# %%
preprocess = True

if preprocess == True:

    train_data_counter = 0
    val_data_counter = 0
    test_data_counter = 0

    for genre in class_1:

        print('Genre:', genre, 'Processed.')
        
        m = hparams['seq_length']

        filelist = os.listdir(dataset_root + '/dataset/' + genre)
        
        for file in filelist[0:70]:
            features = extract_features(dataset_root + '/dataset/' + genre + '/' + file, hparams)
            for i in range(5):
                train_data_x[train_data_counter, :] = features[:, (i * m): ((i+1) * m)]
                train_data_y[train_data_counter] = tf.keras.utils.to_categorical(0, num_classes=3)
                train_data_counter += 1
        
        for file in filelist[70:90]:
            features = extract_features(dataset_root + '/dataset/' + genre + '/' + file, hparams)
            for i in range(5):
                val_data_x[val_data_counter, :] = features[:, (i * m): ((i+1) * m)]
                val_data_y[val_data_counter] = tf.keras.utils.to_categorical(0, num_classes=3)
                val_data_counter += 1
                
        for file in filelist[90:100]:
            features = extract_features(dataset_root + '/dataset/' + genre + '/' + file, hparams)
            for i in range(5):
                test_data_x[test_data_counter, :] = features[:, (i * m): ((i+1) * m)]
                test_data_y[test_data_counter] = tf.keras.utils.to_categorical(0, num_classes=3)
                test_data_counter += 1
        

    for genre in class_2:

        print('Genre:', genre, 'Processed.')
        
        m = hparams['seq_length']

        filelist = os.listdir(dataset_root + '/dataset/' + genre)
        
        for file in filelist[0:70]:
            features = extract_features(dataset_root + '/dataset/' + genre + '/' + file, hparams)
            for i in range(5):
                train_data_x[train_data_counter, :] = features[:, (i * m): ((i+1) * m)]
                train_data_y[train_data_counter] = tf.keras.utils.to_categorical(1, num_classes=3)
                train_data_counter += 1
        
        for file in filelist[70:90]:
            features = extract_features(dataset_root + '/dataset/' + genre + '/' + file, hparams)
            for i in range(5):
                val_data_x[val_data_counter, :] = features[:, (i * m): ((i+1) * m)]
                val_data_y[val_data_counter] = tf.keras.utils.to_categorical(1, num_classes=3)
                val_data_counter += 1
                
        for file in filelist[90:100]:
            features = extract_features(dataset_root + '/dataset/' + genre + '/' + file, hparams)
            for i in range(5):
                test_data_x[test_data_counter, :] = features[:, (i * m): ((i+1) * m)]
                test_data_y[test_data_counter] = tf.keras.utils.to_categorical(1, num_classes=3)
                test_data_counter += 1
                
    
    for genre in class_3:

        print('Genre:', genre, 'Processed.')
        
        m = hparams['seq_length']

        filelist = os.listdir(dataset_root + '/dataset/' + genre)
        
        for file in filelist[0:70]:
            features = extract_features(dataset_root + '/dataset/' + genre + '/' + file, hparams)
            for i in range(5):
                train_data_x[train_data_counter, :] = features[:, (i * m): ((i+1) * m)]
                train_data_y[train_data_counter] = tf.keras.utils.to_categorical(2, num_classes=3)
                train_data_counter += 1
        
        for file in filelist[70:90]:
            features = extract_features(dataset_root + '/dataset/' + genre + '/' + file, hparams)
            for i in range(5):
                val_data_x[val_data_counter, :] = features[:, (i * m): ((i+1) * m)]
                val_data_y[val_data_counter] = tf.keras.utils.to_categorical(2, num_classes=3)
                val_data_counter += 1
                
        for file in filelist[90:100]:
            features = extract_features(dataset_root + '/dataset/' + genre + '/' + file, hparams)
            for i in range(5):
                test_data_x[test_data_counter, :] = features[:, (i * m): ((i+1) * m)]
                test_data_y[test_data_counter] = tf.keras.utils.to_categorical(2, num_classes=3)
                test_data_counter += 1
            
    if 'prepared' not in os.listdir('.'):
        os.mkdir('prepared')
    np.save('./prepared/train_data_x.npy', train_data_x, allow_pickle=False)
    np.save('./prepared/train_data_y.npy', train_data_y, allow_pickle=False)
    np.save('./prepared/val_data_x.npy', val_data_x, allow_pickle=False)
    np.save('./prepared/val_data_y.npy', val_data_y, allow_pickle=False)
    np.save('./prepared/test_data_x.npy', test_data_x, allow_pickle=False)
    np.save('./prepared/test_data_y.npy', test_data_y, allow_pickle=False)
else:
    train_data_x = np.load('./prepared/train_data_x.npy', allow_pickle=False)
    train_data_y = np.load('./prepared/train_data_y.npy', allow_pickle=False)
    val_data_x = np.load('./prepared/val_data_x.npy', allow_pickle=False)
    val_data_y = np.load('./prepared/val_data_y.npy', allow_pickle=False)
    test_data_x = np.load('./prepared/test_data_x.npy', allow_pickle=False)
    test_data_y = np.load('./prepared/test_data_y.npy', allow_pickle=False)
# Out:
# Genre: hiphop Processed.
# Genre: metal Processed.
# Genre: rock Processed.

# %%
train_data_x  = np.moveaxis(train_data_x, 1, 2)
val_data_x    = np.moveaxis(val_data_x,   1, 2)
test_data_x   = np.moveaxis(test_data_x,  1, 2)

# %% [markdown]
# ### Model Creation and Training:

# %%
class GenreClassifierModel(tf.keras.Model):
    
    def __init__(self, l1, l2):
        
        super().__init__()
        
        self.L1 = tf.keras.layers.LSTM(l1, return_sequences=True)
        self.L2 = tf.keras.layers.LSTM(l2, return_sequences=False)
        self.L3 = tf.keras.layers.Dense(units=hparams['num_classes'], activation="softmax")
        
    def call(self, inputs):
        self.x = self.L1(inputs)
        self.x = self.L2(self.x)
        self.x = self.L3(self.x)
        return self.x

# %% [markdown]
# ### Training Model:

# %%
def create_model(config):
    
    l1 = config['L1']
    l2 = config['L2']
    
    # Model Definition:
    model = GenreClassifierModel(l1, l2)
    
    # Model Compilation:
    model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
    
    return model

# %%
model = create_model({
    'L1': 64,
    'L2': 32
})

# %%
hist = model.fit(train_data_x, train_data_y, epochs=200)
# Out:
# Epoch 1/200
# 33/33 [==============================] - 1s 16ms/step - loss: 1.0160 - accuracy: 0.4810
# Epoch 2/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.9252 - accuracy: 0.5762
# Epoch 3/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.8515 - accuracy: 0.6057
# Epoch 4/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.8468 - accuracy: 0.6267
# Epoch 5/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.8095 - accuracy: 0.6390
# Epoch 6/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.7893 - accuracy: 0.6362
# Epoch 7/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.7521 - accuracy: 0.6571
# Epoch 8/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.7380 - accuracy: 0.6857
# Epoch 9/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.7250 - accuracy: 0.6714
# Epoch 10/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.6987 - accuracy: 0.7162
# Epoch 11/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.7033 - accuracy: 0.7086
# Epoch 12/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.6588 - accuracy: 0.7238
# Epoch 13/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.6678 - accuracy: 0.7200
# Epoch 14/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.6293 - accuracy: 0.7438
# Epoch 15/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.6353 - accuracy: 0.7457
# Epoch 16/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.6349 - accuracy: 0.7352
# Epoch 17/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.6057 - accuracy: 0.7524
# Epoch 18/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.6011 - accuracy: 0.7505
# Epoch 19/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.5844 - accuracy: 0.7495
# Epoch 20/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.5787 - accuracy: 0.7724
# Epoch 21/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.6444 - accuracy: 0.7333
# Epoch 22/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.5690 - accuracy: 0.7667
# Epoch 23/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.5165 - accuracy: 0.8019
# Epoch 24/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.5172 - accuracy: 0.7933
# Epoch 25/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.5176 - accuracy: 0.7886
# Epoch 26/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.4764 - accuracy: 0.8095
# Epoch 27/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.4882 - accuracy: 0.8000
# Epoch 28/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.4839 - accuracy: 0.8038
# Epoch 29/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.4656 - accuracy: 0.8333
# Epoch 30/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.4654 - accuracy: 0.8162
# Epoch 31/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.4787 - accuracy: 0.8029
# Epoch 32/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.4089 - accuracy: 0.8505
# Epoch 33/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.4175 - accuracy: 0.8410
# Epoch 34/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.4310 - accuracy: 0.8343
# Epoch 35/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.4334 - accuracy: 0.8257
# Epoch 36/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.4018 - accuracy: 0.8467
# Epoch 37/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.4400 - accuracy: 0.8286
# Epoch 38/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.3829 - accuracy: 0.8676
# Epoch 39/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.4051 - accuracy: 0.8390
# Epoch 40/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.4281 - accuracy: 0.8362
# Epoch 41/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.4126 - accuracy: 0.8314
# Epoch 42/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.3911 - accuracy: 0.8400
# Epoch 43/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.3936 - accuracy: 0.8400
# Epoch 44/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.4013 - accuracy: 0.8543
# Epoch 45/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.3752 - accuracy: 0.8467
# Epoch 46/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.3805 - accuracy: 0.8381
# Epoch 47/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.3797 - accuracy: 0.8486
# Epoch 48/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.3913 - accuracy: 0.8457
# Epoch 49/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.4091 - accuracy: 0.8543
# Epoch 50/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.3942 - accuracy: 0.8390
# Epoch 51/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.3796 - accuracy: 0.8505
# Epoch 52/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.3718 - accuracy: 0.8590
# Epoch 53/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.3601 - accuracy: 0.8590
# Epoch 54/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.3727 - accuracy: 0.8524
# Epoch 55/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.3376 - accuracy: 0.8676
# Epoch 56/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.3416 - accuracy: 0.8667
# Epoch 57/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.3550 - accuracy: 0.8638
# Epoch 58/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.3318 - accuracy: 0.8657
# Epoch 59/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.3140 - accuracy: 0.8810
# Epoch 60/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.3165 - accuracy: 0.8810
# Epoch 61/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.3083 - accuracy: 0.8733
# Epoch 62/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.2808 - accuracy: 0.8990
# Epoch 63/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.3050 - accuracy: 0.8819
# Epoch 64/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.2670 - accuracy: 0.8933
# Epoch 65/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.2835 - accuracy: 0.8943
# Epoch 66/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.3025 - accuracy: 0.8829
# Epoch 67/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.2982 - accuracy: 0.8886
# Epoch 68/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.2703 - accuracy: 0.8924
# Epoch 69/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.2721 - accuracy: 0.8943
# Epoch 70/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.2752 - accuracy: 0.8886
# Epoch 71/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.2973 - accuracy: 0.8914
# Epoch 72/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.2484 - accuracy: 0.9095
# Epoch 73/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.2902 - accuracy: 0.8914
# Epoch 74/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.2861 - accuracy: 0.8886
# Epoch 75/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.2992 - accuracy: 0.8867
# Epoch 76/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.2364 - accuracy: 0.9086
# Epoch 77/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.2490 - accuracy: 0.9048
# Epoch 78/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.2379 - accuracy: 0.9029
# Epoch 79/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.2569 - accuracy: 0.8962
# Epoch 80/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.2230 - accuracy: 0.9133
# Epoch 81/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.2708 - accuracy: 0.9095
# Epoch 82/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.2421 - accuracy: 0.9162
# Epoch 83/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.2652 - accuracy: 0.9010
# Epoch 84/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.2539 - accuracy: 0.9019
# Epoch 85/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.2477 - accuracy: 0.9029
# Epoch 86/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.2142 - accuracy: 0.9105
# Epoch 87/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.2311 - accuracy: 0.9095
# Epoch 88/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.1859 - accuracy: 0.9362
# Epoch 89/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.2429 - accuracy: 0.9124
# Epoch 90/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.2497 - accuracy: 0.9067
# Epoch 91/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.1992 - accuracy: 0.9305
# Epoch 92/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.2135 - accuracy: 0.9152
# Epoch 93/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.1680 - accuracy: 0.9333
# Epoch 94/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.2457 - accuracy: 0.9038
# Epoch 95/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.1897 - accuracy: 0.9371
# Epoch 96/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.2101 - accuracy: 0.9171
# Epoch 97/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.2274 - accuracy: 0.9181
# Epoch 98/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.2365 - accuracy: 0.9095
# Epoch 99/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.1541 - accuracy: 0.9467
# Epoch 100/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.2037 - accuracy: 0.9219
# Epoch 101/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.2223 - accuracy: 0.9124
# Epoch 102/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.2266 - accuracy: 0.9219
# Epoch 103/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.1897 - accuracy: 0.9333
# Epoch 104/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.1804 - accuracy: 0.9286
# Epoch 105/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.1879 - accuracy: 0.9219
# Epoch 106/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.1635 - accuracy: 0.9333
# Epoch 107/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.1716 - accuracy: 0.9314
# Epoch 108/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.1971 - accuracy: 0.9238
# Epoch 109/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.1893 - accuracy: 0.9324
# Epoch 110/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.1761 - accuracy: 0.9410
# Epoch 111/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.1669 - accuracy: 0.9371
# Epoch 112/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.1897 - accuracy: 0.9295
# Epoch 113/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.1790 - accuracy: 0.9381
# Epoch 114/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.1574 - accuracy: 0.9400
# Epoch 115/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.1642 - accuracy: 0.9333
# Epoch 116/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.1644 - accuracy: 0.9343
# Epoch 117/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.1698 - accuracy: 0.9371
# Epoch 118/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.1847 - accuracy: 0.9371
# Epoch 119/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.1560 - accuracy: 0.9438
# Epoch 120/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.1547 - accuracy: 0.9410
# Epoch 121/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.1748 - accuracy: 0.9390
# Epoch 122/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.1801 - accuracy: 0.9362
# Epoch 123/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.1418 - accuracy: 0.9495
# Epoch 124/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.1616 - accuracy: 0.9438
# Epoch 125/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.1686 - accuracy: 0.9400
# Epoch 126/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.1882 - accuracy: 0.9295
# Epoch 127/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.1731 - accuracy: 0.9400
# Epoch 128/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.1672 - accuracy: 0.9448
# Epoch 129/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.1345 - accuracy: 0.9505
# Epoch 130/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.1280 - accuracy: 0.9486
# Epoch 131/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.1553 - accuracy: 0.9400
# Epoch 132/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.1382 - accuracy: 0.9505
# Epoch 133/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.1350 - accuracy: 0.9533
# Epoch 134/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.1223 - accuracy: 0.9524
# Epoch 135/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.1212 - accuracy: 0.9505
# Epoch 136/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.1536 - accuracy: 0.9476
# Epoch 137/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.1466 - accuracy: 0.9448
# Epoch 138/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.1461 - accuracy: 0.9476
# Epoch 139/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.1554 - accuracy: 0.9457
# Epoch 140/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.1285 - accuracy: 0.9543
# Epoch 141/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.1468 - accuracy: 0.9457
# Epoch 142/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.1187 - accuracy: 0.9638
# Epoch 143/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.1367 - accuracy: 0.9610
# Epoch 144/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.1425 - accuracy: 0.9524
# Epoch 145/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.1385 - accuracy: 0.9505
# Epoch 146/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0863 - accuracy: 0.9714
# Epoch 147/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.2073 - accuracy: 0.9352
# Epoch 148/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.1093 - accuracy: 0.9648
# Epoch 149/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.1469 - accuracy: 0.9438
# Epoch 150/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.1336 - accuracy: 0.9524
# Epoch 151/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.1298 - accuracy: 0.9533
# Epoch 152/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0958 - accuracy: 0.9638
# Epoch 153/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.1163 - accuracy: 0.9543
# Epoch 154/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.1703 - accuracy: 0.9438
# Epoch 155/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.1255 - accuracy: 0.9562
# Epoch 156/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.1054 - accuracy: 0.9638
# Epoch 157/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.1460 - accuracy: 0.9486
# Epoch 158/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.1393 - accuracy: 0.9467
# Epoch 159/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.1101 - accuracy: 0.9657
# Epoch 160/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.1139 - accuracy: 0.9600
# Epoch 161/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0964 - accuracy: 0.9676
# Epoch 162/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.1022 - accuracy: 0.9657
# Epoch 163/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.1998 - accuracy: 0.9333
# Epoch 164/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0829 - accuracy: 0.9733
# Epoch 165/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.1147 - accuracy: 0.9581
# Epoch 166/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0803 - accuracy: 0.9705
# Epoch 167/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.1193 - accuracy: 0.9581
# Epoch 168/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.1115 - accuracy: 0.9552
# Epoch 169/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0910 - accuracy: 0.9648
# Epoch 170/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0889 - accuracy: 0.9676
# Epoch 171/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.1349 - accuracy: 0.9552
# Epoch 172/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.1165 - accuracy: 0.9581
# Epoch 173/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0919 - accuracy: 0.9695
# Epoch 174/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.1134 - accuracy: 0.9676
# Epoch 175/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0986 - accuracy: 0.9733
# Epoch 176/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.1033 - accuracy: 0.9676
# Epoch 177/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0840 - accuracy: 0.9743
# Epoch 178/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0975 - accuracy: 0.9676
# Epoch 179/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0575 - accuracy: 0.9848
# Epoch 180/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.1013 - accuracy: 0.9676
# Epoch 181/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.1697 - accuracy: 0.9429
# Epoch 182/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0714 - accuracy: 0.9752
# Epoch 183/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0811 - accuracy: 0.9771
# Epoch 184/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.1037 - accuracy: 0.9657
# Epoch 185/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0634 - accuracy: 0.9790
# Epoch 186/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0811 - accuracy: 0.9724
# Epoch 187/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0874 - accuracy: 0.9762
# Epoch 188/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0744 - accuracy: 0.9752
# Epoch 189/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0822 - accuracy: 0.9733
# Epoch 190/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0864 - accuracy: 0.9686
# Epoch 191/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0814 - accuracy: 0.9686
# Epoch 192/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0655 - accuracy: 0.9743
# Epoch 193/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0844 - accuracy: 0.9771
# Epoch 194/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0903 - accuracy: 0.9762
# Epoch 195/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0788 - accuracy: 0.9781
# Epoch 196/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0999 - accuracy: 0.9686
# Epoch 197/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.2061 - accuracy: 0.9429
# Epoch 198/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.1060 - accuracy: 0.9638
# Epoch 199/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0717 - accuracy: 0.9752
# Epoch 200/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.0804 - accuracy: 0.9733

# %%
model.evaluate(val_data_x, val_data_y)
# Out:
# 10/10 [==============================] - 0s 9ms/step - loss: 1.0584 - accuracy: 0.8000
# [1.0583808422088623, 0.800000011920929]

# %%
model.save('./models/model')
# Out:
# WARNING:tensorflow:From /home/tankgauravgt/miniconda3/envs/mir/lib/python3.8/site-packages/tensorflow/python/ops/resource_variable_ops.py:1813: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: ./models/model/assets
