# %%
import tensorflow as tf
import sklearn as skl
import librosa as lr
import numpy as np
import logging
import os

# %%
logging.warnings.filterwarnings('ignore')

# %% [markdown]
# ### Genre Selection:

# %%
genres = {
    'blues': 0,
    'classical': 1,
    'country': 2,
    'disco': 3,
    'hiphop': 4,
    'jazz': 5,
    'metal': 6,
    'pop': 7,
    'reggae': 8,
    'rock': 9
}

# %% [markdown]
# ### Hyper Parameters:

# %%
hparams = {
    'samplerate': 22050,
    'seq_length': 256,
    'hop_length': 512,
    'fft_window': 2048,
    'num_classes': len(genres)
}

# %% [markdown]
# ### Extract Features:

# %%
def extract_features(filepath, hparams):
    
    audio_data_array = lr.load(filepath, sr=hparams['samplerate'], mono=True)
    
    features = [
        
        # MFCC Features:
        lr.feature.mfcc(
            y          = audio_data_array[0],
            sr         = hparams['samplerate'],
            hop_length = hparams['hop_length'],
            n_fft      = hparams['fft_window']
        ),

        # Chroma STFT:
        lr.feature.chroma_stft(
            y          = audio_data_array[0],
            sr         = hparams['samplerate'],
            hop_length = hparams['hop_length'],
            n_fft      = hparams['fft_window']
        ),
        
        # Spectral Centroid:
        lr.feature.spectral_centroid(
            y          = audio_data_array[0],
            sr         = hparams['samplerate'],
            hop_length = hparams['hop_length'],
            n_fft      = hparams['fft_window']
        ),
        
        # Spectral Contrast:
        lr.feature.spectral_contrast(
            y          = audio_data_array[0],
            sr         = hparams['samplerate'],
            hop_length = hparams['hop_length'],
            n_fft      = hparams['fft_window']
        )
    ]
    
    # features[0] = skl.preprocessing.scale(features[0], axis=1)
    # features[1] = skl.preprocessing.scale(features[1], axis=1)
    # features[2] = skl.preprocessing.minmax_scale(features[2], axis=0)
    # features[3] = skl.preprocessing.minmax_scale(features[3], axis=1)
    
    return np.vstack(features)

# %% [markdown]
# ### Creating Dataset:

# %%
train_x = np.zeros(shape=(5 * 70 * hparams['num_classes'], 40, hparams['seq_length']))
val_x   = np.zeros(shape=(5 * 20 * hparams['num_classes'], 40, hparams['seq_length']))
test_x  = np.zeros(shape=(5 * 10 * hparams['num_classes'], 40, hparams['seq_length']))

# %% [markdown]
# ##### Generate Train Dataset if not exist:

# %%
if not os.path.exists('./prepared/train_x.npy'):
    train_counter = 0
    for genre in genres.keys():
        m = hparams['seq_length']
        train_filenames = sorted(os.listdir('./dataset/' + genre))[0:70]
        for i in range(70):
            train_example = extract_features(
                './dataset/' + genre + '/' + train_filenames[i], 
                hparams
            )
            for j in range(5):
                train_x[train_counter, :] = train_example[:, (j*m):(j+1)*m]
                train_counter += 1
            print('Train Files Loaded:', train_counter // 5)

    if 'prepared' not in os.listdir('.'):
        os.mkdir('prepared')
    np.save('./prepared/train_x.npy', train_x, allow_pickle=False)
else:
    train_x = np.load('./prepared/train_x.npy', allow_pickle=False)
# Out:
# Train Files Loaded: 1
# Train Files Loaded: 2
# Train Files Loaded: 3
# Train Files Loaded: 4
# Train Files Loaded: 5
# Train Files Loaded: 6
# Train Files Loaded: 7
# Train Files Loaded: 8
# Train Files Loaded: 9
# Train Files Loaded: 10
# Train Files Loaded: 11
# Train Files Loaded: 12
# Train Files Loaded: 13
# Train Files Loaded: 14
# Train Files Loaded: 15
# Train Files Loaded: 16
# Train Files Loaded: 17
# Train Files Loaded: 18
# Train Files Loaded: 19
# Train Files Loaded: 20
# Train Files Loaded: 21
# Train Files Loaded: 22
# Train Files Loaded: 23
# Train Files Loaded: 24
# Train Files Loaded: 25
# Train Files Loaded: 26
# Train Files Loaded: 27
# Train Files Loaded: 28
# Train Files Loaded: 29
# Train Files Loaded: 30
# Train Files Loaded: 31
# Train Files Loaded: 32
# Train Files Loaded: 33
# Train Files Loaded: 34
# Train Files Loaded: 35
# Train Files Loaded: 36
# Train Files Loaded: 37
# Train Files Loaded: 38
# Train Files Loaded: 39
# Train Files Loaded: 40
# Train Files Loaded: 41
# Train Files Loaded: 42
# Train Files Loaded: 43
# Train Files Loaded: 44
# Train Files Loaded: 45
# Train Files Loaded: 46
# Train Files Loaded: 47
# Train Files Loaded: 48
# Train Files Loaded: 49
# Train Files Loaded: 50
# Train Files Loaded: 51
# Train Files Loaded: 52
# Train Files Loaded: 53
# Train Files Loaded: 54
# Train Files Loaded: 55
# Train Files Loaded: 56
# Train Files Loaded: 57
# Train Files Loaded: 58
# Train Files Loaded: 59
# Train Files Loaded: 60
# Train Files Loaded: 61
# Train Files Loaded: 62
# Train Files Loaded: 63
# Train Files Loaded: 64
# Train Files Loaded: 65
# Train Files Loaded: 66
# Train Files Loaded: 67
# Train Files Loaded: 68
# Train Files Loaded: 69
# Train Files Loaded: 70
# Train Files Loaded: 71
# Train Files Loaded: 72
# Train Files Loaded: 73
# Train Files Loaded: 74
# Train Files Loaded: 75
# Train Files Loaded: 76
# Train Files Loaded: 77
# Train Files Loaded: 78
# Train Files Loaded: 79
# Train Files Loaded: 80
# Train Files Loaded: 81
# Train Files Loaded: 82
# Train Files Loaded: 83
# Train Files Loaded: 84
# Train Files Loaded: 85
# Train Files Loaded: 86
# Train Files Loaded: 87
# Train Files Loaded: 88
# Train Files Loaded: 89
# Train Files Loaded: 90
# Train Files Loaded: 91
# Train Files Loaded: 92
# Train Files Loaded: 93
# Train Files Loaded: 94
# Train Files Loaded: 95
# Train Files Loaded: 96
# Train Files Loaded: 97
# Train Files Loaded: 98
# Train Files Loaded: 99
# Train Files Loaded: 100
# Train Files Loaded: 101
# Train Files Loaded: 102
# Train Files Loaded: 103
# Train Files Loaded: 104
# Train Files Loaded: 105
# Train Files Loaded: 106
# Train Files Loaded: 107
# Train Files Loaded: 108
# Train Files Loaded: 109
# Train Files Loaded: 110
# Train Files Loaded: 111
# Train Files Loaded: 112
# Train Files Loaded: 113
# Train Files Loaded: 114
# Train Files Loaded: 115
# Train Files Loaded: 116
# Train Files Loaded: 117
# Train Files Loaded: 118
# Train Files Loaded: 119
# Train Files Loaded: 120
# Train Files Loaded: 121
# Train Files Loaded: 122
# Train Files Loaded: 123
# Train Files Loaded: 124
# Train Files Loaded: 125
# Train Files Loaded: 126
# Train Files Loaded: 127
# Train Files Loaded: 128
# Train Files Loaded: 129
# Train Files Loaded: 130
# Train Files Loaded: 131
# Train Files Loaded: 132
# Train Files Loaded: 133
# Train Files Loaded: 134
# Train Files Loaded: 135
# Train Files Loaded: 136
# Train Files Loaded: 137
# Train Files Loaded: 138
# Train Files Loaded: 139
# Train Files Loaded: 140
# Train Files Loaded: 141
# Train Files Loaded: 142
# Train Files Loaded: 143
# Train Files Loaded: 144
# Train Files Loaded: 145
# Train Files Loaded: 146
# Train Files Loaded: 147
# Train Files Loaded: 148
# Train Files Loaded: 149
# Train Files Loaded: 150
# Train Files Loaded: 151
# Train Files Loaded: 152
# Train Files Loaded: 629
# Train Files Loaded: 630
# Train Files Loaded: 631
# Train Files Loaded: 632
# Train Files Loaded: 633
# Train Files Loaded: 634
# Train Files Loaded: 635
# Train Files Loaded: 636
# Train Files Loaded: 637
# Train Files Loaded: 638
# Train Files Loaded: 639
# Train Files Loaded: 640
# Train Files Loaded: 641
# Train Files Loaded: 642
# Train Files Loaded: 643
# Train Files Loaded: 644
# Train Files Loaded: 645
# Train Files Loaded: 646
# Train Files Loaded: 647
# Train Files Loaded: 648
# Train Files Loaded: 649
# Train Files Loaded: 650
# Train Files Loaded: 651
# Train Files Loaded: 652
# Train Files Loaded: 653
# Train Files Loaded: 654
# Train Files Loaded: 655
# Train Files Loaded: 656
# Train Files Loaded: 657
# Train Files Loaded: 658
# Train Files Loaded: 659
# Train Files Loaded: 660
# Train Files Loaded: 661
# Train Files Loaded: 662
# Train Files Loaded: 663
# Train Files Loaded: 664
# Train Files Loaded: 665
# Train Files Loaded: 666
# Train Files Loaded: 667
# Train Files Loaded: 668
# Train Files Loaded: 669
# Train Files Loaded: 670
# Train Files Loaded: 671
# Train Files Loaded: 672
# Train Files Loaded: 673
# Train Files Loaded: 674
# Train Files Loaded: 675
# Train Files Loaded: 676
# Train Files Loaded: 677
# Train Files Loaded: 678
# Train Files Loaded: 679
# Train Files Loaded: 680
# Train Files Loaded: 681
# Train Files Loaded: 682
# Train Files Loaded: 683
# Train Files Loaded: 684
# Train Files Loaded: 685
# Train Files Loaded: 686
# Train Files Loaded: 687
# Train Files Loaded: 688
# Train Files Loaded: 689
# Train Files Loaded: 690
# Train Files Loaded: 691
# Train Files Loaded: 692
# Train Files Loaded: 693
# Train Files Loaded: 694
# Train Files Loaded: 695
# Train Files Loaded: 696
# Train Files Loaded: 697
# Train Files Loaded: 698
# Train Files Loaded: 699
# Train Files Loaded: 700

# %% [markdown]
# ##### Generate Validation Dataset if not exist:

# %%
if not os.path.exists('./prepared/val_x.npy'):
    val_counter   = 0
    for genre in genres.keys():
        m = hparams['seq_length']
        val_filenames   = sorted(os.listdir('./dataset/' + genre))[70:90]
        for i in range(20):
            val_example = extract_features(
                './dataset/' + genre + '/' + val_filenames[i], 
                hparams
            )
            for j in range(5):
                val_x[val_counter, :] = val_example[:, (j*m):(j+1)*m]
                val_counter += 1
            print('Validation Files Loaded:', val_counter // 5)
            
    if 'prepared' not in os.listdir('.'):
        os.mkdir('prepared')
    np.save('./prepared/val_x.npy', val_x, allow_pickle=False)
else:
    val_x = np.load('./prepared/val_x.npy', allow_pickle=False)
# Out:
# Validation Files Loaded: 1
# Validation Files Loaded: 2
# Validation Files Loaded: 3
# Validation Files Loaded: 4
# Validation Files Loaded: 5
# Validation Files Loaded: 6
# Validation Files Loaded: 7
# Validation Files Loaded: 8
# Validation Files Loaded: 9
# Validation Files Loaded: 10
# Validation Files Loaded: 11
# Validation Files Loaded: 12
# Validation Files Loaded: 13
# Validation Files Loaded: 14
# Validation Files Loaded: 15
# Validation Files Loaded: 16
# Validation Files Loaded: 17
# Validation Files Loaded: 18
# Validation Files Loaded: 19
# Validation Files Loaded: 20
# Validation Files Loaded: 21
# Validation Files Loaded: 22
# Validation Files Loaded: 23
# Validation Files Loaded: 24
# Validation Files Loaded: 25
# Validation Files Loaded: 26
# Validation Files Loaded: 27
# Validation Files Loaded: 28
# Validation Files Loaded: 29
# Validation Files Loaded: 30
# Validation Files Loaded: 31
# Validation Files Loaded: 32
# Validation Files Loaded: 33
# Validation Files Loaded: 34
# Validation Files Loaded: 35
# Validation Files Loaded: 36
# Validation Files Loaded: 37
# Validation Files Loaded: 38
# Validation Files Loaded: 39
# Validation Files Loaded: 40
# Validation Files Loaded: 41
# Validation Files Loaded: 42
# Validation Files Loaded: 43
# Validation Files Loaded: 44
# Validation Files Loaded: 45
# Validation Files Loaded: 46
# Validation Files Loaded: 47
# Validation Files Loaded: 48
# Validation Files Loaded: 49
# Validation Files Loaded: 50
# Validation Files Loaded: 51
# Validation Files Loaded: 52
# Validation Files Loaded: 53
# Validation Files Loaded: 54
# Validation Files Loaded: 55
# Validation Files Loaded: 56
# Validation Files Loaded: 57
# Validation Files Loaded: 58
# Validation Files Loaded: 59
# Validation Files Loaded: 60
# Validation Files Loaded: 61
# Validation Files Loaded: 62
# Validation Files Loaded: 63
# Validation Files Loaded: 64
# Validation Files Loaded: 65
# Validation Files Loaded: 66
# Validation Files Loaded: 67
# Validation Files Loaded: 68
# Validation Files Loaded: 69
# Validation Files Loaded: 70
# Validation Files Loaded: 71
# Validation Files Loaded: 72
# Validation Files Loaded: 73
# Validation Files Loaded: 74
# Validation Files Loaded: 75
# Validation Files Loaded: 76
# Validation Files Loaded: 77
# Validation Files Loaded: 78
# Validation Files Loaded: 79
# Validation Files Loaded: 80
# Validation Files Loaded: 81
# Validation Files Loaded: 82
# Validation Files Loaded: 83
# Validation Files Loaded: 84
# Validation Files Loaded: 85
# Validation Files Loaded: 86
# Validation Files Loaded: 87
# Validation Files Loaded: 88
# Validation Files Loaded: 89
# Validation Files Loaded: 90
# Validation Files Loaded: 91
# Validation Files Loaded: 92
# Validation Files Loaded: 93
# Validation Files Loaded: 94
# Validation Files Loaded: 95
# Validation Files Loaded: 96
# Validation Files Loaded: 97
# Validation Files Loaded: 98
# Validation Files Loaded: 99
# Validation Files Loaded: 100
# Validation Files Loaded: 101
# Validation Files Loaded: 102
# Validation Files Loaded: 103
# Validation Files Loaded: 104
# Validation Files Loaded: 105
# Validation Files Loaded: 106
# Validation Files Loaded: 107
# Validation Files Loaded: 108
# Validation Files Loaded: 109
# Validation Files Loaded: 110
# Validation Files Loaded: 111
# Validation Files Loaded: 112
# Validation Files Loaded: 113
# Validation Files Loaded: 114
# Validation Files Loaded: 115
# Validation Files Loaded: 116
# Validation Files Loaded: 117
# Validation Files Loaded: 118
# Validation Files Loaded: 119
# Validation Files Loaded: 120
# Validation Files Loaded: 121
# Validation Files Loaded: 122
# Validation Files Loaded: 123
# Validation Files Loaded: 124
# Validation Files Loaded: 125
# Validation Files Loaded: 126
# Validation Files Loaded: 127
# Validation Files Loaded: 128
# Validation Files Loaded: 129
# Validation Files Loaded: 130
# Validation Files Loaded: 131
# Validation Files Loaded: 132
# Validation Files Loaded: 133
# Validation Files Loaded: 134
# Validation Files Loaded: 135
# Validation Files Loaded: 136
# Validation Files Loaded: 137
# Validation Files Loaded: 138
# Validation Files Loaded: 139
# Validation Files Loaded: 140
# Validation Files Loaded: 141
# Validation Files Loaded: 142
# Validation Files Loaded: 143
# Validation Files Loaded: 144
# Validation Files Loaded: 145
# Validation Files Loaded: 146
# Validation Files Loaded: 147
# Validation Files Loaded: 148
# Validation Files Loaded: 149
# Validation Files Loaded: 150
# Validation Files Loaded: 151
# Validation Files Loaded: 152
# Validation Files Loaded: 153
# Validation Files Loaded: 154
# Validation Files Loaded: 155
# Validation Files Loaded: 156
# Validation Files Loaded: 157
# Validation Files Loaded: 158
# Validation Files Loaded: 159
# Validation Files Loaded: 160
# Validation Files Loaded: 161
# Validation Files Loaded: 162
# Validation Files Loaded: 163
# Validation Files Loaded: 164
# Validation Files Loaded: 165
# Validation Files Loaded: 166
# Validation Files Loaded: 167
# Validation Files Loaded: 168
# Validation Files Loaded: 169
# Validation Files Loaded: 170
# Validation Files Loaded: 171
# Validation Files Loaded: 172
# Validation Files Loaded: 173
# Validation Files Loaded: 174
# Validation Files Loaded: 175
# Validation Files Loaded: 176
# Validation Files Loaded: 177
# Validation Files Loaded: 178
# Validation Files Loaded: 179
# Validation Files Loaded: 180
# Validation Files Loaded: 181
# Validation Files Loaded: 182
# Validation Files Loaded: 183
# Validation Files Loaded: 184
# Validation Files Loaded: 185
# Validation Files Loaded: 186
# Validation Files Loaded: 187
# Validation Files Loaded: 188
# Validation Files Loaded: 189
# Validation Files Loaded: 190
# Validation Files Loaded: 191
# Validation Files Loaded: 192
# Validation Files Loaded: 193
# Validation Files Loaded: 194
# Validation Files Loaded: 195
# Validation Files Loaded: 196
# Validation Files Loaded: 197
# Validation Files Loaded: 198
# Validation Files Loaded: 199
# Validation Files Loaded: 200

# %% [markdown]
# ##### Generate Test Dataset if not exist:

# %%
if not os.path.exists('./prepared/test_x.npy'):
    test_counter   = 0
    for genre in genres.keys():
        m = hparams['seq_length']
        test_filenames   = sorted(os.listdir('./dataset/' + genre))[90:100]
        for i in range(10):
            test_example = extract_features(
                './dataset/' + genre + '/' + test_filenames[i], 
                hparams
            )
            for j in range(5):
                test_x[test_counter, :] = test_example[:, (j*m):(j+1)*m]
                test_counter += 1
            print('testidation Files Loaded:', test_counter // 5)
            
    if 'prepared' not in os.listdir('.'):
        os.mkdir('prepared')
    np.save('./prepared/test_x.npy', test_x, allow_pickle=False)
else:
    test_x = np.load('./prepared/test_x.npy', allow_pickle=False)
# Out:
# testidation Files Loaded: 1
# testidation Files Loaded: 2
# testidation Files Loaded: 3
# testidation Files Loaded: 4
# testidation Files Loaded: 5
# testidation Files Loaded: 6
# testidation Files Loaded: 7
# testidation Files Loaded: 8
# testidation Files Loaded: 9
# testidation Files Loaded: 10
# testidation Files Loaded: 11
# testidation Files Loaded: 12
# testidation Files Loaded: 13
# testidation Files Loaded: 14
# testidation Files Loaded: 15
# testidation Files Loaded: 16
# testidation Files Loaded: 17
# testidation Files Loaded: 18
# testidation Files Loaded: 19
# testidation Files Loaded: 20
# testidation Files Loaded: 21
# testidation Files Loaded: 22
# testidation Files Loaded: 23
# testidation Files Loaded: 24
# testidation Files Loaded: 25
# testidation Files Loaded: 26
# testidation Files Loaded: 27
# testidation Files Loaded: 28
# testidation Files Loaded: 29
# testidation Files Loaded: 30
# testidation Files Loaded: 31
# testidation Files Loaded: 32
# testidation Files Loaded: 33
# testidation Files Loaded: 34
# testidation Files Loaded: 35
# testidation Files Loaded: 36
# testidation Files Loaded: 37
# testidation Files Loaded: 38
# testidation Files Loaded: 39
# testidation Files Loaded: 40
# testidation Files Loaded: 41
# testidation Files Loaded: 42
# testidation Files Loaded: 43
# testidation Files Loaded: 44
# testidation Files Loaded: 45
# testidation Files Loaded: 46
# testidation Files Loaded: 47
# testidation Files Loaded: 48
# testidation Files Loaded: 49
# testidation Files Loaded: 50
# testidation Files Loaded: 51
# testidation Files Loaded: 52
# testidation Files Loaded: 53
# testidation Files Loaded: 54
# testidation Files Loaded: 55
# testidation Files Loaded: 56
# testidation Files Loaded: 57
# testidation Files Loaded: 58
# testidation Files Loaded: 59
# testidation Files Loaded: 60
# testidation Files Loaded: 61
# testidation Files Loaded: 62
# testidation Files Loaded: 63
# testidation Files Loaded: 64
# testidation Files Loaded: 65
# testidation Files Loaded: 66
# testidation Files Loaded: 67
# testidation Files Loaded: 68
# testidation Files Loaded: 69
# testidation Files Loaded: 70
# testidation Files Loaded: 71
# testidation Files Loaded: 72
# testidation Files Loaded: 73
# testidation Files Loaded: 74
# testidation Files Loaded: 75
# testidation Files Loaded: 76
# testidation Files Loaded: 77
# testidation Files Loaded: 78
# testidation Files Loaded: 79
# testidation Files Loaded: 80
# testidation Files Loaded: 81
# testidation Files Loaded: 82
# testidation Files Loaded: 83
# testidation Files Loaded: 84
# testidation Files Loaded: 85
# testidation Files Loaded: 86
# testidation Files Loaded: 87
# testidation Files Loaded: 88
# testidation Files Loaded: 89
# testidation Files Loaded: 90
# testidation Files Loaded: 91
# testidation Files Loaded: 92
# testidation Files Loaded: 93
# testidation Files Loaded: 94
# testidation Files Loaded: 95
# testidation Files Loaded: 96
# testidation Files Loaded: 97
# testidation Files Loaded: 98
# testidation Files Loaded: 99
# testidation Files Loaded: 100

# %% [markdown]
# ### Ground Truth Labels:

# %%
train_y = np.zeros(shape=(5 * 70 * hparams['num_classes'], hparams['num_classes']), dtype=float)
val_y   = np.zeros(shape=(5 * 20 * hparams['num_classes'], hparams['num_classes']), dtype=float)
test_y  = np.zeros(shape=(5 * 10 * hparams['num_classes'], hparams['num_classes']), dtype=float)

train_counter = 0
val_counter   = 0
test_counter  = 0

for i in range(5 * 70 * hparams['num_classes']):
    train_y[train_counter, :] = tf.keras.utils.to_categorical(train_counter // (5*70), num_classes=hparams['num_classes'])
    train_counter += 1

for i in range(5 * 20 * hparams['num_classes']):
    val_y[val_counter, :] = tf.keras.utils.to_categorical(val_counter // (5*20), num_classes=hparams['num_classes'])
    val_counter += 1
        
for i in range(5 * 10 * hparams['num_classes']):
    test_y[test_counter, :] = tf.keras.utils.to_categorical(test_counter // (5*10), num_classes=hparams['num_classes'])
    test_counter += 1

# %%
train_x = np.moveaxis(train_x, 1, 2)
val_x = np.moveaxis(val_x, 1, 2)
test_x = np.moveaxis(test_x, 1, 2)

# %%
class GenreClassifierModel(tf.keras.Model):
    
    def __init__(self):
        super().__init__()
        
        self.L1 = tf.keras.layers.LSTM(64, return_sequences=True)
        self.L2 = tf.keras.layers.LSTM(64, return_sequences=False)
        self.L3 = tf.keras.layers.Dense(64, activation='relu')
        self.L4 = tf.keras.layers.Dropout(0.3)
        self.L5 = tf.keras.layers.Dense(units=hparams['num_classes'], activation="softmax")
        
    def call(self, inputs):
        self.x = self.L1(inputs)
        self.x = self.L2(self.x)
        self.x = self.L3(self.x)
        self.x = self.L4(self.x)
        self.x = self.L5(self.x)
        return self.x

# %%
model = GenreClassifierModel()

# %%
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
hist = model.fit(train_x, train_y, epochs=30)
# Out:
# Epoch 1/30
# 110/110 [==============================] - 3s 31ms/step - loss: 2.2925 - accuracy: 0.1217
# Epoch 2/30
# 110/110 [==============================] - 3s 31ms/step - loss: 2.1497 - accuracy: 0.2200
# Epoch 3/30
# 110/110 [==============================] - 3s 30ms/step - loss: 1.9265 - accuracy: 0.3117
# Epoch 4/30
# 110/110 [==============================] - 3s 30ms/step - loss: 1.7375 - accuracy: 0.3803
# Epoch 5/30
# 110/110 [==============================] - 3s 31ms/step - loss: 1.5859 - accuracy: 0.4234
# Epoch 6/30
# 110/110 [==============================] - 3s 32ms/step - loss: 1.4781 - accuracy: 0.4631
# Epoch 7/30
# 110/110 [==============================] - 3s 31ms/step - loss: 1.3786 - accuracy: 0.4989
# Epoch 8/30
# 110/110 [==============================] - 3s 29ms/step - loss: 1.2839 - accuracy: 0.5331
# Epoch 9/30
# 110/110 [==============================] - 3s 30ms/step - loss: 1.1943 - accuracy: 0.5729
# Epoch 10/30
# 110/110 [==============================] - 4s 32ms/step - loss: 1.1171 - accuracy: 0.5960
# Epoch 11/30
# 110/110 [==============================] - 3s 31ms/step - loss: 1.0433 - accuracy: 0.6289
# Epoch 12/30
# 110/110 [==============================] - 3s 30ms/step - loss: 0.9512 - accuracy: 0.6594
# Epoch 13/30
# 110/110 [==============================] - 3s 31ms/step - loss: 0.8915 - accuracy: 0.6831
# Epoch 14/30
# 110/110 [==============================] - 3s 31ms/step - loss: 0.8255 - accuracy: 0.7043
# Epoch 15/30
# 110/110 [==============================] - 3s 29ms/step - loss: 0.7688 - accuracy: 0.7234
# Epoch 16/30
# 110/110 [==============================] - 3s 31ms/step - loss: 0.6678 - accuracy: 0.7731
# Epoch 17/30
# 110/110 [==============================] - 3s 31ms/step - loss: 0.6053 - accuracy: 0.7923
# Epoch 18/30
# 110/110 [==============================] - 3s 30ms/step - loss: 0.5722 - accuracy: 0.7969
# Epoch 19/30
# 110/110 [==============================] - 3s 30ms/step - loss: 0.5303 - accuracy: 0.8191
# Epoch 20/30
# 110/110 [==============================] - 3s 31ms/step - loss: 0.4648 - accuracy: 0.8451
# Epoch 21/30
# 110/110 [==============================] - 3s 31ms/step - loss: 0.4305 - accuracy: 0.8620
# Epoch 22/30
# 110/110 [==============================] - 4s 32ms/step - loss: 0.3995 - accuracy: 0.8663
# Epoch 23/30
# 110/110 [==============================] - 3s 30ms/step - loss: 0.3745 - accuracy: 0.8769
# Epoch 24/30
# 110/110 [==============================] - 4s 33ms/step - loss: 0.3551 - accuracy: 0.8823
# Epoch 25/30
# 110/110 [==============================] - 3s 31ms/step - loss: 0.3014 - accuracy: 0.9049
# Epoch 26/30
# 110/110 [==============================] - 3s 29ms/step - loss: 0.3095 - accuracy: 0.8980
# Epoch 27/30
# 110/110 [==============================] - 3s 31ms/step - loss: 0.2651 - accuracy: 0.9154
# Epoch 28/30
# 110/110 [==============================] - 3s 30ms/step - loss: 0.2694 - accuracy: 0.9126
# Epoch 29/30
# 110/110 [==============================] - 4s 34ms/step - loss: 0.2200 - accuracy: 0.9289
# Epoch 30/30
# 110/110 [==============================] - 4s 33ms/step - loss: 0.2227 - accuracy: 0.9317

# %%
model.evaluate(val_x, val_y)
# Out:
# 32/32 [==============================] - 1s 17ms/step - loss: 3.9246 - accuracy: 0.3670
# [3.924561023712158, 0.367000013589859]

# %%
gno = 0

g = list(genres.keys())[gno]
print('Actual Genre', g, gno)

for i in range(hparams['num_classes']):

    m = hparams['seq_length']
    
    example = extract_features('./dataset/{}/{}.000'.format(g, g) + str(90+i) + '.wav', hparams)
    
    segment_1 = np.moveaxis(example, 0, 1)[0*m:1*m, :].reshape(1, m, 40)
    segment_2 = np.moveaxis(example, 0, 1)[1*m:2*m, :].reshape(1, m, 40)
    segment_3 = np.moveaxis(example, 0, 1)[2*m:3*m, :].reshape(1, m, 40)
    segment_4 = np.moveaxis(example, 0, 1)[3*m:4*m, :].reshape(1, m, 40)
    segment_5 = np.moveaxis(example, 0, 1)[4*m:5*m, :].reshape(1, m, 40)
    
    print('===============================================')
    print('Segment-0:', np.argmax(model.predict(segment_1)))
    print('Segment-1:', np.argmax(model.predict(segment_2)))
    print('Segment-2:', np.argmax(model.predict(segment_3)))
    print('Segment-3:', np.argmax(model.predict(segment_4)))
    print('Segment-4:', np.argmax(model.predict(segment_5)))
# Out:
# Actual Genre blues 0
# ===============================================
# Segment-0: 0
# Segment-1: 0
# Segment-2: 9
# Segment-3: 9
# Segment-4: 0
# ===============================================
# Segment-0: 8
# Segment-1: 2
# Segment-2: 0
# Segment-3: 8
# Segment-4: 2
# ===============================================
# Segment-0: 0
# Segment-1: 0
# Segment-2: 5
# Segment-3: 0
# Segment-4: 0
# ===============================================
# Segment-0: 5
# Segment-1: 1
# Segment-2: 0
# Segment-3: 5
# Segment-4: 0
# ===============================================
# Segment-0: 9
# Segment-1: 0
# Segment-2: 8
# Segment-3: 4
# Segment-4: 0
# ===============================================
# Segment-0: 5
# Segment-1: 3
# Segment-2: 0
# Segment-3: 2
# Segment-4: 2
# ===============================================
# Segment-0: 1
# Segment-1: 1
# Segment-2: 2
# Segment-3: 5
# Segment-4: 2
# ===============================================
# Segment-0: 8
# Segment-1: 8
# Segment-2: 8
# Segment-3: 9
# Segment-4: 9
# ===============================================
# Segment-0: 6
# Segment-1: 0
# Segment-2: 9
# Segment-3: 0
# Segment-4: 9
# ===============================================
# Segment-0: 9
# Segment-1: 0
# Segment-2: 8
# Segment-3: 2
# Segment-4: 9
