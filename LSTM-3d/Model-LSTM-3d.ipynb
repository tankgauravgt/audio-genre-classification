# %%
from scipy.io.wavfile import read as read_wav
from IPython.display import Audio
import matplotlib.pyplot as plt
import tensorflow as tf
import sklearn as skl
import librosa as lr
import numpy as np
import logging
import random
import scipy
import os

# %%
np.random.seed(5)
logging.warnings.filterwarnings('ignore')

# %%
dataset_root = '..'

# %% [markdown]
# ### Genre Dictionary:

# %%
genres = {
    'jazz': 0,
    'classical': 1,
    'blues': 2
}

# %% [markdown]
# ### Hyper Parameters:

# %%
hparams = {
    'samplerate': 22050,
    'seq_length': 256,
    'hop_length': 512,
    'fft_window': 2048,
    'num_classes': len(genres)
}

# %% [markdown]
# ### Extract Features:

# %%
def extract_features(filepath, hparams):
    
    audio_data_array = lr.load(filepath, sr=hparams['samplerate'], mono=True)
    
    normalized = lr.util.normalize(audio_data_array[0])
    
    features = [
        
        # MFCC Features:
        lr.feature.mfcc(
            y          = audio_data_array[0],
            sr         = hparams['samplerate'],
            hop_length = hparams['hop_length'],
            n_fft      = hparams['fft_window']
        ),

        # Chroma STFT:
        lr.feature.chroma_stft(
            y          = audio_data_array[0],
            sr         = hparams['samplerate'],
            hop_length = hparams['hop_length'],
            n_fft      = hparams['fft_window']
        ),
        
        # Spectral Centroid:
        lr.feature.spectral_centroid(
            y          = audio_data_array[0],
            sr         = hparams['samplerate'],
            hop_length = hparams['hop_length'],
            n_fft      = hparams['fft_window']
        ),
        
        # Spectral Contrast:
        lr.feature.spectral_contrast(
            y          = audio_data_array[0],
            sr         = hparams['samplerate'],
            hop_length = hparams['hop_length'],
            n_fft      = hparams['fft_window']
        )
    ]
    
    return np.vstack(features)

# %% [markdown]
# ### Jazz Class:

# %%
class_1 = [
    'jazz'
]

# %% [markdown]
# ### Classical Class:

# %%
class_2 = [
    'classical'
]

# %% [markdown]
# ### Blues Class:

# %%
class_3 = [
    'blues'
]

# %% [markdown]
# ### Allocating Arrays to Store Dataset:

# %%
train_data_x = np.zeros(shape=(5 * 210, 40, hparams['seq_length']))
val_data_x = np.zeros(shape=(5 * 60, 40, hparams['seq_length']))
test_data_x = np.zeros(shape=(5 * 30, 40, hparams['seq_length']))

train_data_y = np.zeros(shape=(5 * 210, 3))
val_data_y = np.zeros(shape=(5 * 60, 3))
test_data_y = np.zeros(shape=(5 * 30, 3))

# %% [markdown]
# ### Train Dataset:

# %%
preprocess = True

if preprocess == True:

    train_data_counter = 0
    val_data_counter = 0
    test_data_counter = 0

    for genre in class_1:

        print('Genre:', genre, 'Processed.')
        
        m = hparams['seq_length']

        filelist = os.listdir(dataset_root + '/dataset/' + genre)
        
        for file in filelist[0:70]:
            features = extract_features(dataset_root + '/dataset/' + genre + '/' + file, hparams)
            for i in range(5):
                train_data_x[train_data_counter, :] = features[:, (i * m): ((i+1) * m)]
                train_data_y[train_data_counter] = tf.keras.utils.to_categorical(0, num_classes=3)
                train_data_counter += 1
        
        for file in filelist[70:90]:
            features = extract_features(dataset_root + '/dataset/' + genre + '/' + file, hparams)
            for i in range(5):
                val_data_x[val_data_counter, :] = features[:, (i * m): ((i+1) * m)]
                val_data_y[val_data_counter] = tf.keras.utils.to_categorical(0, num_classes=3)
                val_data_counter += 1
                
        for file in filelist[90:100]:
            features = extract_features(dataset_root + '/dataset/' + genre + '/' + file, hparams)
            for i in range(5):
                test_data_x[test_data_counter, :] = features[:, (i * m): ((i+1) * m)]
                test_data_y[test_data_counter] = tf.keras.utils.to_categorical(0, num_classes=3)
                test_data_counter += 1
        

    for genre in class_2:

        print('Genre:', genre, 'Processed.')
        
        m = hparams['seq_length']

        filelist = os.listdir(dataset_root + '/dataset/' + genre)
        
        for file in filelist[0:70]:
            features = extract_features(dataset_root + '/dataset/' + genre + '/' + file, hparams)
            for i in range(5):
                train_data_x[train_data_counter, :] = features[:, (i * m): ((i+1) * m)]
                train_data_y[train_data_counter] = tf.keras.utils.to_categorical(1, num_classes=3)
                train_data_counter += 1
        
        for file in filelist[70:90]:
            features = extract_features(dataset_root + '/dataset/' + genre + '/' + file, hparams)
            for i in range(5):
                val_data_x[val_data_counter, :] = features[:, (i * m): ((i+1) * m)]
                val_data_y[val_data_counter] = tf.keras.utils.to_categorical(1, num_classes=3)
                val_data_counter += 1
                
        for file in filelist[90:100]:
            features = extract_features(dataset_root + '/dataset/' + genre + '/' + file, hparams)
            for i in range(5):
                test_data_x[test_data_counter, :] = features[:, (i * m): ((i+1) * m)]
                test_data_y[test_data_counter] = tf.keras.utils.to_categorical(1, num_classes=3)
                test_data_counter += 1
                
    
    for genre in class_3:

        print('Genre:', genre, 'Processed.')
        
        m = hparams['seq_length']

        filelist = os.listdir(dataset_root + '/dataset/' + genre)
        
        for file in filelist[0:70]:
            features = extract_features(dataset_root + '/dataset/' + genre + '/' + file, hparams)
            for i in range(5):
                train_data_x[train_data_counter, :] = features[:, (i * m): ((i+1) * m)]
                train_data_y[train_data_counter] = tf.keras.utils.to_categorical(2, num_classes=3)
                train_data_counter += 1
        
        for file in filelist[70:90]:
            features = extract_features(dataset_root + '/dataset/' + genre + '/' + file, hparams)
            for i in range(5):
                val_data_x[val_data_counter, :] = features[:, (i * m): ((i+1) * m)]
                val_data_y[val_data_counter] = tf.keras.utils.to_categorical(2, num_classes=3)
                val_data_counter += 1
                
        for file in filelist[90:100]:
            features = extract_features(dataset_root + '/dataset/' + genre + '/' + file, hparams)
            for i in range(5):
                test_data_x[test_data_counter, :] = features[:, (i * m): ((i+1) * m)]
                test_data_y[test_data_counter] = tf.keras.utils.to_categorical(2, num_classes=3)
                test_data_counter += 1
            
    if 'prepared' not in os.listdir('.'):
        os.mkdir('prepared')
    np.save('./prepared/train_data_x.npy', train_data_x, allow_pickle=False)
    np.save('./prepared/train_data_y.npy', train_data_y, allow_pickle=False)
    np.save('./prepared/val_data_x.npy', val_data_x, allow_pickle=False)
    np.save('./prepared/val_data_y.npy', val_data_y, allow_pickle=False)
    np.save('./prepared/test_data_x.npy', test_data_x, allow_pickle=False)
    np.save('./prepared/test_data_y.npy', test_data_y, allow_pickle=False)
else:
    train_data_x = np.load('./prepared/train_data_x.npy', allow_pickle=False)
    train_data_y = np.load('./prepared/train_data_y.npy', allow_pickle=False)
    val_data_x = np.load('./prepared/val_data_x.npy', allow_pickle=False)
    val_data_y = np.load('./prepared/val_data_y.npy', allow_pickle=False)
    test_data_x = np.load('./prepared/test_data_x.npy', allow_pickle=False)
    test_data_y = np.load('./prepared/test_data_y.npy', allow_pickle=False)
# Out:
# Genre: jazz Processed.
# Genre: classical Processed.
# Genre: blues Processed.

# %%
train_data_x  = np.moveaxis(train_data_x, 1, 2)
val_data_x    = np.moveaxis(val_data_x,   1, 2)
test_data_x   = np.moveaxis(test_data_x,  1, 2)

# %% [markdown]
# ### Model Creation and Training:

# %%
class GenreClassifierModel(tf.keras.Model):
    
    def __init__(self, l1, l2):
        
        super().__init__()
        
        self.L1 = tf.keras.layers.LSTM(l1, return_sequences=True)
        self.L2 = tf.keras.layers.LSTM(l2, return_sequences=False)
        self.L3 = tf.keras.layers.Dense(units=hparams['num_classes'], activation="softmax")
        
    def call(self, inputs):
        self.x = self.L1(inputs)
        self.x = self.L2(self.x)
        self.x = self.L3(self.x)
        return self.x

# %% [markdown]
# ### Training Model:

# %%
def create_model(config):
    
    l1 = config['L1']
    l2 = config['L2']
    
    # Model Definition:
    model = GenreClassifierModel(l1, l2)
    
    # Model Compilation:
    model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
    
    return model

# %%
model = create_model({
    'L1': 64,
    'L2': 32
})

# %%
hist = model.fit(train_data_x, train_data_y, epochs=200)
# Out:
# Epoch 1/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.9078 - accuracy: 0.5800
# Epoch 2/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.7122 - accuracy: 0.6810
# Epoch 3/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.6175 - accuracy: 0.7410
# Epoch 4/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.5577 - accuracy: 0.7810
# Epoch 5/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.5561 - accuracy: 0.7810
# Epoch 6/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.4957 - accuracy: 0.8219
# Epoch 7/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.4710 - accuracy: 0.8010
# Epoch 8/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.4660 - accuracy: 0.8295
# Epoch 9/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.4424 - accuracy: 0.8476
# Epoch 10/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.4609 - accuracy: 0.8429
# Epoch 11/200
# 33/33 [==============================] - 1s 16ms/step - loss: 0.4912 - accuracy: 0.8067
# Epoch 12/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.3725 - accuracy: 0.8590
# Epoch 13/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.4007 - accuracy: 0.8533
# Epoch 14/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.3367 - accuracy: 0.8867
# Epoch 15/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.3195 - accuracy: 0.8848
# Epoch 16/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.3911 - accuracy: 0.8571
# Epoch 17/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.3380 - accuracy: 0.8743
# Epoch 18/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.2964 - accuracy: 0.8981
# Epoch 19/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.2802 - accuracy: 0.9010
# Epoch 20/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.2748 - accuracy: 0.9019
# Epoch 21/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.2658 - accuracy: 0.9067
# Epoch 22/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.2808 - accuracy: 0.9029
# Epoch 23/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.2629 - accuracy: 0.9067
# Epoch 24/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.2943 - accuracy: 0.8905
# Epoch 25/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.2466 - accuracy: 0.9152
# Epoch 26/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.2378 - accuracy: 0.9181
# Epoch 27/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.2462 - accuracy: 0.9048
# Epoch 28/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.2292 - accuracy: 0.9152
# Epoch 29/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.2418 - accuracy: 0.9171
# Epoch 30/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.2169 - accuracy: 0.9257
# Epoch 31/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.2692 - accuracy: 0.9105
# Epoch 32/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.2248 - accuracy: 0.9162
# Epoch 33/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.1630 - accuracy: 0.9457
# Epoch 34/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.1629 - accuracy: 0.9457
# Epoch 35/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.2234 - accuracy: 0.9295
# Epoch 36/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.2116 - accuracy: 0.9295
# Epoch 37/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.2064 - accuracy: 0.9267
# Epoch 38/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.1607 - accuracy: 0.9486
# Epoch 39/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.1775 - accuracy: 0.9343
# Epoch 40/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.1527 - accuracy: 0.9467
# Epoch 41/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.1525 - accuracy: 0.9495
# Epoch 42/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.1514 - accuracy: 0.9524
# Epoch 43/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.1674 - accuracy: 0.9429
# Epoch 44/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.1522 - accuracy: 0.9467
# Epoch 45/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.1489 - accuracy: 0.9495
# Epoch 46/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.1294 - accuracy: 0.9543
# Epoch 47/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.1817 - accuracy: 0.9457
# Epoch 48/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.1050 - accuracy: 0.9676
# Epoch 49/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.1377 - accuracy: 0.9419
# Epoch 50/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.1150 - accuracy: 0.9543
# Epoch 51/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.1056 - accuracy: 0.9610
# Epoch 52/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.1441 - accuracy: 0.9514
# Epoch 53/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.1174 - accuracy: 0.9629
# Epoch 54/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.1162 - accuracy: 0.9600
# Epoch 55/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.0944 - accuracy: 0.9667
# Epoch 56/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.1020 - accuracy: 0.9657
# Epoch 57/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0836 - accuracy: 0.9714
# Epoch 58/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.1049 - accuracy: 0.9590
# Epoch 59/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.1035 - accuracy: 0.9610
# Epoch 60/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0949 - accuracy: 0.9714
# Epoch 61/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0719 - accuracy: 0.9724
# Epoch 62/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0986 - accuracy: 0.9657
# Epoch 63/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0842 - accuracy: 0.9695
# Epoch 64/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0982 - accuracy: 0.9667
# Epoch 65/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0728 - accuracy: 0.9752
# Epoch 66/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0798 - accuracy: 0.9705
# Epoch 67/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.1037 - accuracy: 0.9686
# Epoch 68/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.1082 - accuracy: 0.9638
# Epoch 69/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.0835 - accuracy: 0.9752
# Epoch 70/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0634 - accuracy: 0.9790
# Epoch 71/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0924 - accuracy: 0.9705
# Epoch 72/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.0990 - accuracy: 0.9695
# Epoch 73/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0689 - accuracy: 0.9781
# Epoch 74/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0821 - accuracy: 0.9686
# Epoch 75/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0630 - accuracy: 0.9790
# Epoch 76/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0552 - accuracy: 0.9819
# Epoch 77/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0450 - accuracy: 0.9838
# Epoch 78/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.1057 - accuracy: 0.9752
# Epoch 79/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0534 - accuracy: 0.9781
# Epoch 80/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0491 - accuracy: 0.9800
# Epoch 81/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0800 - accuracy: 0.9733
# Epoch 82/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0974 - accuracy: 0.9667
# Epoch 83/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0506 - accuracy: 0.9800
# Epoch 84/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0733 - accuracy: 0.9810
# Epoch 85/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0325 - accuracy: 0.9905
# Epoch 86/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0584 - accuracy: 0.9810
# Epoch 87/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0783 - accuracy: 0.9705
# Epoch 88/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0480 - accuracy: 0.9800
# Epoch 89/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0587 - accuracy: 0.9838
# Epoch 90/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.0523 - accuracy: 0.9810
# Epoch 91/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0618 - accuracy: 0.9819
# Epoch 92/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0397 - accuracy: 0.9895
# Epoch 93/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0645 - accuracy: 0.9781
# Epoch 94/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0635 - accuracy: 0.9762
# Epoch 95/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0448 - accuracy: 0.9857
# Epoch 96/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0341 - accuracy: 0.9895
# Epoch 97/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.1131 - accuracy: 0.9619
# Epoch 98/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0548 - accuracy: 0.9838
# Epoch 99/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0216 - accuracy: 0.9933
# Epoch 100/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.0594 - accuracy: 0.9838
# Epoch 101/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0428 - accuracy: 0.9848
# Epoch 102/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0323 - accuracy: 0.9895
# Epoch 103/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0569 - accuracy: 0.9857
# Epoch 104/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0396 - accuracy: 0.9867
# Epoch 105/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0605 - accuracy: 0.9810
# Epoch 106/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0252 - accuracy: 0.9886
# Epoch 107/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0148 - accuracy: 0.9962
# Epoch 108/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0570 - accuracy: 0.9838
# Epoch 109/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0793 - accuracy: 0.9733
# Epoch 110/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0600 - accuracy: 0.9771
# Epoch 111/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0579 - accuracy: 0.9838
# Epoch 112/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0547 - accuracy: 0.9857
# Epoch 113/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0395 - accuracy: 0.9895
# Epoch 114/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0380 - accuracy: 0.9924
# Epoch 115/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0316 - accuracy: 0.9905
# Epoch 116/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0273 - accuracy: 0.9914
# Epoch 117/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0531 - accuracy: 0.9876
# Epoch 118/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0359 - accuracy: 0.9876
# Epoch 119/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0355 - accuracy: 0.9895
# Epoch 120/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0263 - accuracy: 0.9914
# Epoch 121/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0210 - accuracy: 0.9886
# Epoch 122/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0630 - accuracy: 0.9867
# Epoch 123/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0729 - accuracy: 0.9771
# Epoch 124/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0357 - accuracy: 0.9886
# Epoch 125/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0293 - accuracy: 0.9905
# Epoch 126/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0169 - accuracy: 0.9962
# Epoch 127/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.0386 - accuracy: 0.9886
# Epoch 128/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0775 - accuracy: 0.9838
# Epoch 129/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0159 - accuracy: 0.9952
# Epoch 130/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0783 - accuracy: 0.9790
# Epoch 131/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0525 - accuracy: 0.9790
# Epoch 132/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0272 - accuracy: 0.9876
# Epoch 133/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0237 - accuracy: 0.9933
# Epoch 134/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0149 - accuracy: 0.9962
# Epoch 135/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0208 - accuracy: 0.9943
# Epoch 136/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0523 - accuracy: 0.9848
# Epoch 137/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0348 - accuracy: 0.9886
# Epoch 138/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.0219 - accuracy: 0.9914
# Epoch 139/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0439 - accuracy: 0.9829
# Epoch 140/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0097 - accuracy: 0.9990
# Epoch 141/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0626 - accuracy: 0.9810
# Epoch 142/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0313 - accuracy: 0.9895
# Epoch 143/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0110 - accuracy: 0.9943
# Epoch 144/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0664 - accuracy: 0.9867
# Epoch 145/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0078 - accuracy: 0.9981
# Epoch 146/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0423 - accuracy: 0.9867
# Epoch 147/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0214 - accuracy: 0.9971
# Epoch 148/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0302 - accuracy: 0.9886
# Epoch 149/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0223 - accuracy: 0.9933
# Epoch 150/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0731 - accuracy: 0.9829
# Epoch 151/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0227 - accuracy: 0.9914
# Epoch 152/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0093 - accuracy: 0.9981
# Epoch 153/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0395 - accuracy: 0.9914
# Epoch 154/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0228 - accuracy: 0.9905
# Epoch 155/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0304 - accuracy: 0.9895
# Epoch 156/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0182 - accuracy: 0.9933
# Epoch 157/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0201 - accuracy: 0.9943
# Epoch 158/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0224 - accuracy: 0.9914
# Epoch 159/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0438 - accuracy: 0.9914
# Epoch 160/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0093 - accuracy: 0.9971
# Epoch 161/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0311 - accuracy: 0.9905
# Epoch 162/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0224 - accuracy: 0.9924
# Epoch 163/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0208 - accuracy: 0.9971
# Epoch 164/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0339 - accuracy: 0.9924
# Epoch 165/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0115 - accuracy: 0.9962
# Epoch 166/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0404 - accuracy: 0.9895
# Epoch 167/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0038 - accuracy: 0.9981
# Epoch 168/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0329 - accuracy: 0.9924
# Epoch 169/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0046 - accuracy: 0.9981
# Epoch 170/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0207 - accuracy: 0.9943
# Epoch 171/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0253 - accuracy: 0.9933
# Epoch 172/200
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0060 - accuracy: 0.9990
# Epoch 173/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0267 - accuracy: 0.9895
# Epoch 174/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0265 - accuracy: 0.9933
# Epoch 175/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0317 - accuracy: 0.9914
# Epoch 176/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 177/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0236 - accuracy: 0.9952
# Epoch 178/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0283 - accuracy: 0.9905
# Epoch 179/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0069 - accuracy: 0.9971
# Epoch 180/200
# 33/33 [==============================] - 1s 17ms/step - loss: 9.4608e-04 - accuracy: 1.0000
# Epoch 181/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0566 - accuracy: 0.9895
# Epoch 182/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0270 - accuracy: 0.9943
# Epoch 183/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 184/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0215 - accuracy: 0.9943
# Epoch 185/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0412 - accuracy: 0.9895
# Epoch 186/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0046 - accuracy: 0.9981
# Epoch 187/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0404 - accuracy: 0.9895
# Epoch 188/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0705 - accuracy: 0.9876
# Epoch 189/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0257 - accuracy: 0.9943
# Epoch 190/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 191/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0152 - accuracy: 0.9971
# Epoch 192/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0532 - accuracy: 0.9876
# Epoch 193/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0171 - accuracy: 0.9943
# Epoch 194/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0184 - accuracy: 0.9971
# Epoch 195/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0586 - accuracy: 0.9867
# Epoch 196/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0342 - accuracy: 0.9886
# Epoch 197/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0398 - accuracy: 0.9886
# Epoch 198/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0399 - accuracy: 0.9895
# Epoch 199/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0198 - accuracy: 0.9943
# Epoch 200/200
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0246 - accuracy: 0.9914

# %%
model.evaluate(val_data_x, val_data_y)
# Out:
# 10/10 [==============================] - 0s 9ms/step - loss: 0.5358 - accuracy: 0.9033
# [0.5358467698097229, 0.903333306312561]

# %%
model.save('./models/model')
# Out:
# WARNING:tensorflow:From /home/tankgauravgt/miniconda3/envs/mir/lib/python3.8/site-packages/tensorflow/python/ops/resource_variable_ops.py:1813: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: ./models/model/assets
