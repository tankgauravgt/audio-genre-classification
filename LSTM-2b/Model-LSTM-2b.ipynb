# %%
from scipy.io.wavfile import read as read_wav
from IPython.display import Audio
import matplotlib.pyplot as plt
import tensorflow as tf
import sklearn as skl
import librosa as lr
import numpy as np
import logging
import random
import scipy
import os

# %%
np.random.seed(5)
logging.warnings.filterwarnings('ignore')

# %%
dataset_root = '..'

# %% [markdown]
# ### Genre Dictionary:

# %%
genres = {
    'submild_1': 0,
    'submild_2': 1
}

# %% [markdown]
# ### Hyper Parameters:

# %%
hparams = {
    'samplerate': 22050,
    'seq_length': 256,
    'hop_length': 512,
    'fft_window': 2048,
    'num_classes': len(genres)
}

# %% [markdown]
# ### Extract Features:

# %%
def extract_features(filepath, hparams):
    
    audio_data_array = lr.load(filepath, sr=hparams['samplerate'], mono=True)
    
    # normalized = lr.util.normalize(audio_data_array[0])
    
    features = [
        
        # MFCC Features:
        lr.feature.mfcc(
            y          = audio_data_array[0],
            sr         = hparams['samplerate'],
            hop_length = hparams['hop_length'],
            n_fft      = hparams['fft_window']
        ),

        # Chroma STFT:
        lr.feature.chroma_stft(
            y          = audio_data_array[0],
            sr         = hparams['samplerate'],
            hop_length = hparams['hop_length'],
            n_fft      = hparams['fft_window']
        ),
        
        # Spectral Centroid:
        lr.feature.spectral_centroid(
            y          = audio_data_array[0],
            sr         = hparams['samplerate'],
            hop_length = hparams['hop_length'],
            n_fft      = hparams['fft_window']
        ),
        
        # Spectral Contrast:
        lr.feature.spectral_contrast(
            y          = audio_data_array[0],
            sr         = hparams['samplerate'],
            hop_length = hparams['hop_length'],
            n_fft      = hparams['fft_window']
        )
    ]
    
    return np.vstack(features)

# %% [markdown]
# ### Submild-1 Classes Array:

# %%
submild_1_classes = [
    'disco',
    'country'
]

# %% [markdown]
# ### Submild-2 Classes Array:

# %%
submild_2_classes = [
    'jazz',
    'classical',
    'blues'
]

# %% [markdown]
# ### Allocating Arrays to Store Dataset:

# %%
train_data_x = np.zeros(shape=(5 * 350, 40, hparams['seq_length']))
val_data_x = np.zeros(shape=(5 * 100, 40, hparams['seq_length']))
test_data_x = np.zeros(shape=(5 * 50, 40, hparams['seq_length']))

train_data_y = np.zeros(shape=(5 * 350, 2))
val_data_y = np.zeros(shape=(5 * 100, 2))
test_data_y = np.zeros(shape=(5 * 50, 2))

# %% [markdown]
# ### Train Dataset:

# %%
preprocess = True

if preprocess == True:

    train_data_counter = 0
    val_data_counter = 0
    test_data_counter = 0

    for genre in submild_1_classes:

        print('Genre:', genre, 'Processed.')
        
        m = hparams['seq_length']

        filelist = os.listdir(dataset_root + '/dataset/' + genre)

        for file in filelist[0:70]:
            features = extract_features(dataset_root + '/dataset/' + genre + '/' + file, hparams)
            for i in range(5):
                train_data_x[train_data_counter, :] = features[:, (i * m): ((i+1) * m)]
                train_data_y[train_data_counter] = tf.keras.utils.to_categorical(0, num_classes=2)
                train_data_counter += 1
        
        for file in filelist[70:90]:
            features = extract_features(dataset_root + '/dataset/' + genre + '/' + file, hparams)
            for i in range(5):
                val_data_x[val_data_counter, :] = features[:, (i * m): ((i+1) * m)]
                val_data_y[val_data_counter] = tf.keras.utils.to_categorical(0, num_classes=2)
                val_data_counter += 1
                
        for file in filelist[90:100]:
            features = extract_features(dataset_root + '/dataset/' + genre + '/' + file, hparams)
            for i in range(5):
                test_data_x[test_data_counter, :] = features[:, (i * m): ((i+1) * m)]
                test_data_y[test_data_counter] = tf.keras.utils.to_categorical(0, num_classes=2)
                test_data_counter += 1
        

    for genre in submild_2_classes:

        print('Genre:', genre, 'Processed.')
        
        m = hparams['seq_length']

        filelist = os.listdir(dataset_root + '/dataset/' + genre)
        
        for file in filelist[0:70]:
            features = extract_features(dataset_root + '/dataset/' + genre + '/' + file, hparams)
            for i in range(5):
                train_data_x[train_data_counter, :] = features[:, (i * m): ((i+1) * m)]
                train_data_y[train_data_counter] = tf.keras.utils.to_categorical(1, num_classes=2)
                train_data_counter += 1
        
        for file in filelist[70:90]:
            features = extract_features(dataset_root + '/dataset/' + genre + '/' + file, hparams)
            for i in range(5):
                val_data_x[val_data_counter, :] = features[:, (i * m): ((i+1) * m)]
                val_data_y[val_data_counter] = tf.keras.utils.to_categorical(1, num_classes=2)
                val_data_counter += 1
                
        for file in filelist[90:100]:
            features = extract_features(dataset_root + '/dataset/' + genre + '/' + file, hparams)
            for i in range(5):
                test_data_x[test_data_counter, :] = features[:, (i * m): ((i+1) * m)]
                test_data_y[test_data_counter] = tf.keras.utils.to_categorical(1, num_classes=2)
                test_data_counter += 1
            
    if 'prepared' not in os.listdir('.'):
        os.mkdir('prepared')
    np.save('./prepared/train_data_x.npy', train_data_x, allow_pickle=False)
    np.save('./prepared/train_data_y.npy', train_data_y, allow_pickle=False)
    np.save('./prepared/val_data_x.npy', val_data_x, allow_pickle=False)
    np.save('./prepared/val_data_y.npy', val_data_y, allow_pickle=False)
    np.save('./prepared/test_data_x.npy', test_data_x, allow_pickle=False)
    np.save('./prepared/test_data_y.npy', test_data_y, allow_pickle=False)
else:
    train_data_x = np.load('./prepared/train_data_x.npy', allow_pickle=False)
    train_data_y = np.load('./prepared/train_data_y.npy', allow_pickle=False)
    val_data_x = np.load('./prepared/val_data_x.npy', allow_pickle=False)
    val_data_y = np.load('./prepared/val_data_y.npy', allow_pickle=False)
    test_data_x = np.load('./prepared/test_data_x.npy', allow_pickle=False)
    test_data_y = np.load('./prepared/test_data_y.npy', allow_pickle=False)
# Out:
# Genre: disco Processed.
# Genre: country Processed.
# Genre: jazz Processed.
# Genre: classical Processed.
# Genre: blues Processed.

# %%
train_data_x  = np.moveaxis(train_data_x, 1, 2)
val_data_x    = np.moveaxis(val_data_x,   1, 2)
test_data_x   = np.moveaxis(test_data_x,  1, 2)

# %% [markdown]
# ### Model Creation and Training:

# %%
class GenreClassifierModel(tf.keras.Model):
    
    def __init__(self, l1, l2):
        
        super().__init__()
        
        self.L1 = tf.keras.layers.LSTM(l1, return_sequences=True)
        self.L2 = tf.keras.layers.LSTM(l2, return_sequences=False)
        self.L3 = tf.keras.layers.Dense(units=hparams['num_classes'], activation="softmax")
        
    def call(self, inputs):
        self.x = self.L1(inputs)
        self.x = self.L2(self.x)
        self.x = self.L3(self.x)
        return self.x

# %% [markdown]
# ### Training Model:

# %%
def create_model(config):
    
    l1 = config['L1']
    l2 = config['L2']
    
    # Model Definition:
    model = GenreClassifierModel(l1, l2)
    
    # Model Compilation:
    model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
    
    return model

# %%
model = create_model({
    'L1': 64,
    'L2': 32
})

# %%
hist = model.fit(train_data_x, train_data_y, epochs=200)
# Out:
# Epoch 1/200
# 55/55 [==============================] - 1s 16ms/step - loss: 0.5426 - accuracy: 0.7417
# Epoch 2/200
# 55/55 [==============================] - 1s 16ms/step - loss: 0.5170 - accuracy: 0.7526
# Epoch 3/200
# 55/55 [==============================] - 1s 16ms/step - loss: 0.4965 - accuracy: 0.7611
# Epoch 4/200
# 55/55 [==============================] - 1s 16ms/step - loss: 0.4747 - accuracy: 0.7674
# Epoch 5/200
# 55/55 [==============================] - 1s 16ms/step - loss: 0.4697 - accuracy: 0.7566
# Epoch 6/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.4663 - accuracy: 0.7680
# Epoch 7/200
# 55/55 [==============================] - 1s 16ms/step - loss: 0.4648 - accuracy: 0.7720
# Epoch 8/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.4237 - accuracy: 0.7994
# Epoch 9/200
# 55/55 [==============================] - 1s 15ms/step - loss: 0.4102 - accuracy: 0.8057
# Epoch 10/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.4230 - accuracy: 0.8069
# Epoch 11/200
# 55/55 [==============================] - 1s 16ms/step - loss: 0.4307 - accuracy: 0.8029
# Epoch 12/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.4120 - accuracy: 0.8194
# Epoch 13/200
# 55/55 [==============================] - 1s 16ms/step - loss: 0.3962 - accuracy: 0.8320
# Epoch 14/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.4130 - accuracy: 0.8263
# Epoch 15/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.3959 - accuracy: 0.8229
# Epoch 16/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.3889 - accuracy: 0.8234
# Epoch 17/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.4122 - accuracy: 0.8143
# Epoch 18/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.3723 - accuracy: 0.8411
# Epoch 19/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.3905 - accuracy: 0.8246
# Epoch 20/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.3845 - accuracy: 0.8291
# Epoch 21/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.3650 - accuracy: 0.8411
# Epoch 22/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.3593 - accuracy: 0.8451
# Epoch 23/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.3440 - accuracy: 0.8520
# Epoch 24/200
# 55/55 [==============================] - 1s 18ms/step - loss: 0.3367 - accuracy: 0.8503
# Epoch 25/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.3208 - accuracy: 0.8583
# Epoch 26/200
# 55/55 [==============================] - 1s 18ms/step - loss: 0.3194 - accuracy: 0.8623
# Epoch 27/200
# 55/55 [==============================] - 1s 18ms/step - loss: 0.3281 - accuracy: 0.8589
# Epoch 28/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.3198 - accuracy: 0.8674
# Epoch 29/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.3425 - accuracy: 0.8463
# Epoch 30/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.3085 - accuracy: 0.8709
# Epoch 31/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.2951 - accuracy: 0.8737
# Epoch 32/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.2916 - accuracy: 0.8720
# Epoch 33/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.2974 - accuracy: 0.8754
# Epoch 34/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.2891 - accuracy: 0.8783
# Epoch 35/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.3149 - accuracy: 0.8691
# Epoch 36/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.2943 - accuracy: 0.8760
# Epoch 37/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.2913 - accuracy: 0.8743
# Epoch 38/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.2975 - accuracy: 0.8726
# Epoch 39/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.2673 - accuracy: 0.8897
# Epoch 40/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.2684 - accuracy: 0.8863
# Epoch 41/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.2651 - accuracy: 0.8863
# Epoch 42/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.2935 - accuracy: 0.8777
# Epoch 43/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.2601 - accuracy: 0.8846
# Epoch 44/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.2730 - accuracy: 0.8863
# Epoch 45/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.2422 - accuracy: 0.8977
# Epoch 46/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.2550 - accuracy: 0.8971
# Epoch 47/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.2475 - accuracy: 0.9006
# Epoch 48/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.2698 - accuracy: 0.8863
# Epoch 49/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.2622 - accuracy: 0.8903
# Epoch 50/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.2297 - accuracy: 0.9040
# Epoch 51/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.2215 - accuracy: 0.9109
# Epoch 52/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.2067 - accuracy: 0.9149
# Epoch 53/200
# 55/55 [==============================] - 1s 19ms/step - loss: 0.2258 - accuracy: 0.9126
# Epoch 54/200
# 55/55 [==============================] - 1s 18ms/step - loss: 0.2172 - accuracy: 0.9154
# Epoch 55/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.2375 - accuracy: 0.9040
# Epoch 56/200
# 55/55 [==============================] - 1s 16ms/step - loss: 0.2429 - accuracy: 0.9046
# Epoch 57/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.2412 - accuracy: 0.9086
# Epoch 58/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.2083 - accuracy: 0.9200
# Epoch 59/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.2523 - accuracy: 0.9011
# Epoch 60/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.2434 - accuracy: 0.8977
# Epoch 61/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.2047 - accuracy: 0.9211
# Epoch 62/200
# 55/55 [==============================] - 1s 16ms/step - loss: 0.2242 - accuracy: 0.9034
# Epoch 63/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.2132 - accuracy: 0.9137
# Epoch 64/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.2233 - accuracy: 0.9126
# Epoch 65/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.2099 - accuracy: 0.9120
# Epoch 66/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.2106 - accuracy: 0.9189
# Epoch 67/200
# 55/55 [==============================] - 1s 16ms/step - loss: 0.1951 - accuracy: 0.9206
# Epoch 68/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.2089 - accuracy: 0.9171
# Epoch 69/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.2135 - accuracy: 0.9143
# Epoch 70/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.1904 - accuracy: 0.9171
# Epoch 71/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.1937 - accuracy: 0.9240
# Epoch 72/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.1925 - accuracy: 0.9229
# Epoch 73/200
# 55/55 [==============================] - 1s 16ms/step - loss: 0.1996 - accuracy: 0.9189
# Epoch 74/200
# 55/55 [==============================] - 1s 16ms/step - loss: 0.2013 - accuracy: 0.9217
# Epoch 75/200
# 55/55 [==============================] - 1s 16ms/step - loss: 0.1852 - accuracy: 0.9240
# Epoch 76/200
# 55/55 [==============================] - 1s 16ms/step - loss: 0.1892 - accuracy: 0.9211
# Epoch 77/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.1737 - accuracy: 0.9354
# Epoch 78/200
# 55/55 [==============================] - 1s 16ms/step - loss: 0.1852 - accuracy: 0.9303
# Epoch 79/200
# 55/55 [==============================] - 1s 16ms/step - loss: 0.1679 - accuracy: 0.9343
# Epoch 80/200
# 55/55 [==============================] - 1s 16ms/step - loss: 0.1805 - accuracy: 0.9246
# Epoch 81/200
# 55/55 [==============================] - 1s 16ms/step - loss: 0.1809 - accuracy: 0.9263
# Epoch 82/200
# 55/55 [==============================] - 1s 16ms/step - loss: 0.1672 - accuracy: 0.9389
# Epoch 83/200
# 55/55 [==============================] - 1s 16ms/step - loss: 0.2159 - accuracy: 0.9109
# Epoch 84/200
# 55/55 [==============================] - 1s 16ms/step - loss: 0.1806 - accuracy: 0.9286
# Epoch 85/200
# 55/55 [==============================] - 1s 16ms/step - loss: 0.1676 - accuracy: 0.9337
# Epoch 86/200
# 55/55 [==============================] - 1s 16ms/step - loss: 0.1674 - accuracy: 0.9371
# Epoch 87/200
# 55/55 [==============================] - 1s 16ms/step - loss: 0.1688 - accuracy: 0.9320
# Epoch 88/200
# 55/55 [==============================] - 1s 16ms/step - loss: 0.1782 - accuracy: 0.9269
# Epoch 89/200
# 55/55 [==============================] - 1s 16ms/step - loss: 0.1805 - accuracy: 0.9326
# Epoch 90/200
# 55/55 [==============================] - 1s 16ms/step - loss: 0.1722 - accuracy: 0.9331
# Epoch 91/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.1434 - accuracy: 0.9491
# Epoch 92/200
# 55/55 [==============================] - 1s 16ms/step - loss: 0.1621 - accuracy: 0.9411
# Epoch 93/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.1520 - accuracy: 0.9411
# Epoch 94/200
# 55/55 [==============================] - 1s 16ms/step - loss: 0.1727 - accuracy: 0.9349
# Epoch 95/200
# 55/55 [==============================] - 1s 16ms/step - loss: 0.1536 - accuracy: 0.9394
# Epoch 96/200
# 55/55 [==============================] - 1s 16ms/step - loss: 0.1431 - accuracy: 0.9474
# Epoch 97/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.1449 - accuracy: 0.9400
# Epoch 98/200
# 55/55 [==============================] - 1s 16ms/step - loss: 0.1703 - accuracy: 0.9371
# Epoch 99/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.1524 - accuracy: 0.9343
# Epoch 100/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.1549 - accuracy: 0.9366
# Epoch 101/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.1429 - accuracy: 0.9429
# Epoch 102/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.1585 - accuracy: 0.9406
# Epoch 103/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.1544 - accuracy: 0.9389
# Epoch 104/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.1492 - accuracy: 0.9457
# Epoch 105/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.1505 - accuracy: 0.9440
# Epoch 106/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.1349 - accuracy: 0.9497
# Epoch 107/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.1328 - accuracy: 0.9497
# Epoch 108/200
# 55/55 [==============================] - 1s 16ms/step - loss: 0.1723 - accuracy: 0.9377
# Epoch 109/200
# 55/55 [==============================] - 1s 16ms/step - loss: 0.1245 - accuracy: 0.9543
# Epoch 110/200
# 55/55 [==============================] - 1s 16ms/step - loss: 0.1400 - accuracy: 0.9446
# Epoch 111/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.1335 - accuracy: 0.9486
# Epoch 112/200
# 55/55 [==============================] - 1s 16ms/step - loss: 0.1254 - accuracy: 0.9566
# Epoch 113/200
# 55/55 [==============================] - 1s 16ms/step - loss: 0.1278 - accuracy: 0.9497
# Epoch 114/200
# 55/55 [==============================] - 1s 18ms/step - loss: 0.1339 - accuracy: 0.9480
# Epoch 115/200
# 55/55 [==============================] - 1s 16ms/step - loss: 0.1248 - accuracy: 0.9566
# Epoch 116/200
# 55/55 [==============================] - 1s 16ms/step - loss: 0.1268 - accuracy: 0.9577
# Epoch 117/200
# 55/55 [==============================] - 1s 16ms/step - loss: 0.1379 - accuracy: 0.9509
# Epoch 118/200
# 55/55 [==============================] - 1s 16ms/step - loss: 0.1411 - accuracy: 0.9526
# Epoch 119/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.1260 - accuracy: 0.9509
# Epoch 120/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.1244 - accuracy: 0.9577
# Epoch 121/200
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0998 - accuracy: 0.9600
# Epoch 122/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.1119 - accuracy: 0.9543
# Epoch 123/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.1194 - accuracy: 0.9589
# Epoch 124/200
# 55/55 [==============================] - 1s 16ms/step - loss: 0.1095 - accuracy: 0.9611
# Epoch 125/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.1116 - accuracy: 0.9520
# Epoch 126/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.1052 - accuracy: 0.9560
# Epoch 127/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.1131 - accuracy: 0.9509
# Epoch 128/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.1160 - accuracy: 0.9583
# Epoch 129/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.1285 - accuracy: 0.9526
# Epoch 130/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.1101 - accuracy: 0.9606
# Epoch 131/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.1325 - accuracy: 0.9554
# Epoch 132/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0903 - accuracy: 0.9640
# Epoch 133/200
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0814 - accuracy: 0.9709
# Epoch 134/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.1085 - accuracy: 0.9617
# Epoch 135/200
# 55/55 [==============================] - 1s 18ms/step - loss: 0.1366 - accuracy: 0.9497
# Epoch 136/200
# 55/55 [==============================] - 1s 18ms/step - loss: 0.1107 - accuracy: 0.9583
# Epoch 137/200
# 55/55 [==============================] - 1s 18ms/step - loss: 0.1245 - accuracy: 0.9560
# Epoch 138/200
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0963 - accuracy: 0.9623
# Epoch 139/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0923 - accuracy: 0.9651
# Epoch 140/200
# 55/55 [==============================] - 1s 18ms/step - loss: 0.1058 - accuracy: 0.9691
# Epoch 141/200
# 55/55 [==============================] - 1s 16ms/step - loss: 0.1173 - accuracy: 0.9611
# Epoch 142/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0650 - accuracy: 0.9766
# Epoch 143/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0854 - accuracy: 0.9663
# Epoch 144/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0979 - accuracy: 0.9680
# Epoch 145/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0996 - accuracy: 0.9617
# Epoch 146/200
# 55/55 [==============================] - 1s 18ms/step - loss: 0.1009 - accuracy: 0.9646
# Epoch 147/200
# 55/55 [==============================] - 1s 18ms/step - loss: 0.1116 - accuracy: 0.9589
# Epoch 148/200
# 55/55 [==============================] - 1s 18ms/step - loss: 0.1162 - accuracy: 0.9600
# Epoch 149/200
# 55/55 [==============================] - 1s 19ms/step - loss: 0.0849 - accuracy: 0.9674
# Epoch 150/200
# 55/55 [==============================] - 1s 18ms/step - loss: 0.1143 - accuracy: 0.9600
# Epoch 151/200
# 55/55 [==============================] - 1s 18ms/step - loss: 0.1087 - accuracy: 0.9543
# Epoch 152/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0897 - accuracy: 0.9669
# Epoch 153/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0913 - accuracy: 0.9669
# Epoch 154/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.1520 - accuracy: 0.9406
# Epoch 155/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0750 - accuracy: 0.9743
# Epoch 156/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0994 - accuracy: 0.9651
# Epoch 157/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.1218 - accuracy: 0.9554
# Epoch 158/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0715 - accuracy: 0.9743
# Epoch 159/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0807 - accuracy: 0.9743
# Epoch 160/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0867 - accuracy: 0.9749
# Epoch 161/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0841 - accuracy: 0.9680
# Epoch 162/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0993 - accuracy: 0.9634
# Epoch 163/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0723 - accuracy: 0.9709
# Epoch 164/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0911 - accuracy: 0.9697
# Epoch 165/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0829 - accuracy: 0.9726
# Epoch 166/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0909 - accuracy: 0.9720
# Epoch 167/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0774 - accuracy: 0.9720
# Epoch 168/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0642 - accuracy: 0.9766
# Epoch 169/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.1227 - accuracy: 0.9589
# Epoch 170/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0488 - accuracy: 0.9817
# Epoch 171/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.1113 - accuracy: 0.9646
# Epoch 172/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0641 - accuracy: 0.9794
# Epoch 173/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0860 - accuracy: 0.9737
# Epoch 174/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0633 - accuracy: 0.9783
# Epoch 175/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.1201 - accuracy: 0.9497
# Epoch 176/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0780 - accuracy: 0.9749
# Epoch 177/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0728 - accuracy: 0.9726
# Epoch 178/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0746 - accuracy: 0.9743
# Epoch 179/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.1025 - accuracy: 0.9686
# Epoch 180/200
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0489 - accuracy: 0.9817
# Epoch 181/200
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0955 - accuracy: 0.9651
# Epoch 182/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0874 - accuracy: 0.9703
# Epoch 183/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0946 - accuracy: 0.9634
# Epoch 184/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0669 - accuracy: 0.9754
# Epoch 185/200
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0651 - accuracy: 0.9737
# Epoch 186/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0748 - accuracy: 0.9766
# Epoch 187/200
# 55/55 [==============================] - 1s 18ms/step - loss: 0.1042 - accuracy: 0.9669
# Epoch 188/200
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0846 - accuracy: 0.9709
# Epoch 189/200
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0770 - accuracy: 0.9766
# Epoch 190/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0838 - accuracy: 0.9731
# Epoch 191/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0705 - accuracy: 0.9737
# Epoch 192/200
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0727 - accuracy: 0.9749
# Epoch 193/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0752 - accuracy: 0.9749
# Epoch 194/200
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0718 - accuracy: 0.9743
# Epoch 195/200
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0608 - accuracy: 0.9834
# Epoch 196/200
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0705 - accuracy: 0.9754
# Epoch 197/200
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0573 - accuracy: 0.9817
# Epoch 198/200
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0798 - accuracy: 0.9709
# Epoch 199/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0554 - accuracy: 0.9817
# Epoch 200/200
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0621 - accuracy: 0.9777

# %%
model.evaluate(val_data_x, val_data_y)
# Out:
# 16/16 [==============================] - 0s 9ms/step - loss: 0.5259 - accuracy: 0.8600
# [0.5259475708007812, 0.8600000143051147]

# %%
model.save('./models/model')
# Out:
# WARNING:tensorflow:From /home/tankgauravgt/miniconda3/envs/mir/lib/python3.8/site-packages/tensorflow/python/ops/resource_variable_ops.py:1813: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: ./models/model/assets
